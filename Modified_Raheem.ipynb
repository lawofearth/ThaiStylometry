# %%
import json

# %%
with open("sortedListLSH.json", 'r') as f:
        sortedListLSH = json.load(f)

# %%
sortedListLSH
# Out:
# [2.0,
#  1020.0,
#  1458.0,
#  630.0,
#  1365.0,
#  859.0,
#  3.0,
#  1016.0,
#  898.0,
#  904.0,
#  855.0,
#  673.0,
#  626.0,
#  908.0,
#  522.0,
#  530.0,
#  890.0,
#  180.0,
#  883.0,
#  863.0,
#  1272.0,
#  556.0,
#  627.0,
#  1535.0,
#  1364.0,
#  1023.0,
#  113.0,
#  1019.0,
#  1086.0,
#  872.0,
#  619.0,
#  897.0,
#  520.0,
#  1105.0,
#  882.0,
#  861.0,
#  896.0,
#  919.0,
#  893.0,
#  690.0,
#  634.0,
#  1017.0,
#  889.0,
#  557.0,
#  862.0,
#  335.0,
#  210.0,
#  352.0,
#  589.0,
#  1044.0,
#  1116.0,
#  532.0,
#  628.0,
#  637.0,
#  860.0,
#  1022.0,
#  865.0,
#  605.0,
#  869.0,
#  616.0,
#  894.0,
#  76.0,
#  216.0,
#  918.0,
#  19.0,
#  1273.0,
#  880.0,
#  1155.0,
#  900.0,
#  361.0,
#  383.0,
#  510.0,
#  1393.0,
#  512.0,
#  521.0,
#  392.0,
#  1096.0,
#  871.0,
#  1021.0,
#  321.0,
#  1003.0,
#  887.0,
#  674.0,
#  531.0,
#  1391.0,
#  877.0,
#  629.0,
#  1098.0,
#  907.0,
#  252.0,
#  1404.0,
#  868.0,
#  1381.0,
#  602.0,
#  956.0,
#  892.0,
#  641.0,
#  1107.0,
# ...

# %%
sortedListLSH[1]
# Out:
# 1020.0

# %% [markdown]
# doc_to_para_dict as default dict
